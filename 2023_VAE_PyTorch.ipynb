# %% [markdown]
# #Preliminaries

# %% [markdown]
# This code is derived from
#
# https://github.com/Jackson-Kang/Pytorch-VAE-tutorial/blob/master/01_Variational_AutoEncoder.ipynb
#
# Miscellaneous references
# https://slazebni.cs.illinois.edu/spring17/lec12_vae.pdf
#
#
#
# ---
#
# The code was originally written on Colab and run on its default GPUs.
#
# If you are running it on some terminal where maybe torchvision isn't installed then execute the following lines first,
#
# ```
# source /etc/anaconda3/bin/activate
# pip install torchvision
# anaconda-navigator
#
# ```
#
# The above will install torchvision and open the navigator, from which you can select Jupyter and load this file into it - and have fun :)

# %% [markdown]
# ##Introduction to Conditional Distributions & KL-Divergence

# %% [markdown]
# https://www.probabilitycourse.com/chapter1/1_4_0_conditional_probability.php
#
# https://home.ttic.edu/~madhurt/courses/infotheory2021/

# %% [markdown]
# # Introduction to VAE

# %% [markdown]
# Suppose we have two random variables $\vec{x}$ and $\vec{z}$ (hence there is a joint distribution over them) and consider being given two conditional distributions $q(\vec{z}|\vec{x})$ and $p(\vec{z}|\vec{x})$ both of which are trying to approximate the true conditional distribution of $\vec{z}$ given $\vec{x}$. Then we can compute the KL divergence between the two to try to measure the discrepancy between these two descriptions. Towards that we observe the following analysis of this measure of discrepancy (we do an abuse of notation here to use $\vec{z}$ for denoting two different things - in the LHS its labelling the distributions and in the RHS its indexing all possible samples of it),
#
# \begin{align}
# &{\rm KL}(q(\vec{z}|\vec{x})||p(\vec{z}|\vec{x}))\\
# &= \sum_{\vec{z}} q(\vec{z}|\vec{x}) \log \frac{q(\vec{z}|\vec{x})}{p(\vec{z}|\vec{x})}\\
# &= -\sum_{\vec{z}} q(\vec{z}|\vec{x}) \log \frac{p(\vec{z}|\vec{x})}{q(\vec{z}|\vec{x})}\\
# &= -\sum_{\vec{z}} q(\vec{z}|\vec{x})  \left[\log p(\vec{z}|\vec{x}) - \log q(\vec{z}|\vec{x}) \right]\\
# &= -\sum_{\vec{z}} q(\vec{z}|\vec{x}) \left[\log \frac{p(\vec{x}|\vec{z})p(\vec{z})}{p(\vec{x})} - \log q(\vec{z}|\vec{x}) \right]\\
# &= -\sum_{\vec{z}} q(\vec{z}|\vec{x}) \left[\log p(\vec{x}|\vec{z}) + \log p(\vec{z}) - \log p(\vec{x}) - \log q(\vec{z}|\vec{x}) \right]\\
# &= \sum_{\vec{z}} q(\vec{z}|\vec{x}) \left[-\log p(\vec{x}|\vec{z}) - \log p(\vec{z}) + \log p(\vec{x}) + \log q(\vec{z}|\vec{x}) \right]
# \end{align}
#
# The above can be written as,
#
# \begin{align}
# \log p(\vec{x}) = &{\rm KL}(q(\vec{z}|\vec{x})||p(\vec{z}|\vec{x})) - \sum_{\vec{z}} q(\vec{z}|\vec{x}) \left[-\log p(\vec{x}|\vec{z}) - \log p(\vec{z}) + \log q(\vec{z}|\vec{x}) \right]\\
# = &{\rm KL}(q(\vec{z}|\vec{x})||p(\vec{z}|\vec{x})) + \underbrace{\left[ \mathbb{E}_{q} \log p(\vec{x}|\vec{z})  - \mathbb{E}_{q}  \log \frac{q(\vec{z}|\vec{x})}{p(\vec{z})} \right]}_{\bf ELBO = -V.F.E}\\
# \end{align}
#
# >The above argument was done assuming that the $\sum_{\vec{z}}$ makes sense and that necessarily needs a finite number of possible values for the random variable $\vec{z}$. But we shall skip re-writing the above proof for continuous random variables - as needed in this experiment - and shall just assert without proof the veracity of the last equality obtained.
#
# The second term on the LHS is called the "Evidence Lower Bound (ELBO)" -- since because of the non-negativity of the KL (the so-called "variational gap") we can write,
#
# $$ {\rm ELBO} \leq \log p(\vec{x})$$
#
#
# Since $\log p(\vec{x})$ is a constant, and we want to minimize the ${\rm KL}$ term, we can achieve the same by maximizing the ELBO.
# Which is the same as the minimization of its negative i.e the optimization problem that we actually code for is,
#
#
# $$
# \min \Bigg ( \underbrace{\underbrace{- \color{blue}{\mathbb{E}_{q} \log p(\vec{x}|\vec{z})}}_{{\rm ``Reconstruction ~Loss"}}  + \color{red}{ {\rm KL} (  q(\vec{z}|\vec{x}) ||  p(\vec{z})) }}_{``\textbf{Variational Free Energy (V.F.E)}"} \Bigg )
# $$
#
#
# Thus by minimizing the VFE we bring the $p(\vec{z}|\vec{x})$ to be close to the $q(\vec{z}|\vec{x})$ -- thus the process of minimizing the V.F.E. can be seen as an attempt to bring close two different parameterizations of the conditional distribution of $\vec{z}$ given $\vec{x}$. ***We shall see that the two nets to be eventually used essentially play this role of giving these two parameterizations.***
#
# **BUT note that its $p(\vec{x}|\vec{z})$ that occurs in the optimization objective** -- and hence at the end of the training a good $p(\vec{x}|\vec{z})$ will be read off and that in turn reveals the ``unknown" distribution $p(\vec{x})$ via the formula $p(\vec{x}) = \int p(\vec{x}|\vec{z}) p(\vec{z}) d\vec{z}$. **We are very crucially assuming that the last integral here is doable which is what will motivate us to choose simple distributions for $\vec{z}$.**
#
#
#
#
# <!-- We don't want to (cant!) compute the KL divergence analytically, so we'll instead use the Monte Carlo estimate.
#
# $$
# \mathbb{E}_{q}  \log \frac{q(z|x)}{p(z)} = \mathbb{E}_{q} [\log q(z|x) - \log{p(z)}]
# $$ -->

# %% [markdown]
# ##Objective
#
# > Given samples $\vec{x} \sim p(\vec{x})$ we want to uncover the function $p(\vec{x})$ by minimizing the V.F.E over the three distributions that occur in it - which we recall are given in terms of,
#
# > (a) $p(\vec{x} \vert \vec{z})$, the "posterior distribution" w.r.t $\vec{z}$ the ``fictitious" latent r.v
#
# > (b) $q(\vec{z} \vert \vec{x})$ and
#
# > (c) $p(\vec{z})$ the distribution of the "latent variable"
#
# Setting the above objective is essentially tantamount of assuming that the data $\vec{x}$ are indeed samples of a distribution $p(\vec{x})$ which can be obtained as the marginal of a ***"generative model"*** which is a joint distirbution $p(\vec{x},\vec{z})$ over the data $\vec{x}$ and the latent variable $\vec{z}$. This assumption of the factorization "$p(\vec{z},\vec{x}) = p(\vec{x} \vert \vec{z}) \cdot p(\vec{z})$" of this imagined joint distribution over the data and a fictitious latent variable is a key insight that gets the entire field started.
#
#
# Towards achieving the aforesaid objective we recall the following fact about Gaussian distribution and note two key ideas.
#
# ---
# FACTS :
#
# - Given a $d-$dimensional vector $\vec{\mu}$ and a $d-$dimensional invertible symmetric matrix $\Sigma$, We use the following notation to denote the multi-variable Gaussian distribution's p.d.f.,
#
# $${\cal N}(\vec{\mu},\Sigma) = \frac{1}{\sqrt{(2\pi)^d {\rm det}(\Sigma)}} e^{-\frac{1}{2} (\vec{x}-\vec{\mu})^\top \Sigma^{-1} (\vec{x}-\vec{\mu})}  $$
#
# - If $\vec{X} \sim {\cal N}(\vec{\mu},\Sigma)$ as above, then it is equivalent to assuming that $\vec{a}^\top \vec{X}$ is a one dimensional Gaussian distributed random variable for every vector $\vec{a}$ in $d-$dimensions. This gives a more intutive picture of what multivariate Gaussian distributions look like.
#
# - Recall that if $\vec{X} \sim {\cal N}(\vec{\mu},\Sigma)$ then, $a\vec{X} + \vec{b} \sim {\cal N}(a\vec{\mu} + \vec{b},a^2\Sigma)$
#
#   In particular, $\vec{a}{\cal N}(0,I) + \vec{b} \sim  {\cal N}( \vec{b},{\rm diag}(a^2))$
#
#   -- this particular case shall be needed very soon!
#
#
# - Recall ([reference ](https://mr-easy.github.io/2020-04-16-kl-divergence-between-2-gaussian-distributions/)) that we have an expression for exact KL diverergence between two Gaussians in the same dimension. If we have two random variables in $k$ dimensions, $f_i \sim {\cal N}(\vec{\mu_i},\Sigma_i)$ for $i=1,2$ then we have,
#
# $${\rm KL}(f_1 || f_2) = \frac{1}{2} \cdot \left [-k + (\vec{\mu_1} - \vec{\mu_2})^\top \Sigma_2^{-1} (\vec{\mu_1} - \vec{\mu_2}) +  \log \frac{\det (\Sigma_2)}{\det (\Sigma_1)} + {\rm Tr} (\Sigma_2^{-1}\Sigma_1) \right ]$$
#
# $$\text{And in particular,}$$
#
# $${\rm KL}({\cal N}(\vec{\mu},\Sigma) || {\cal N}(0,I) ) =  \frac{1}{2} \cdot \left [-k + \Vert{\vec{\mu}}\Vert^2 + {\rm Tr} (\Sigma) - \log {\det (\Sigma)} \right ] $$
#
#
#
#
# ---

# %% [markdown]
# ##Solution Ideas
#
#
# - The **first key idea** will be exploit the above identity and to model $p(z), p(x \vert z)$ and $q(z | x)$ as Gaussian distributions.
#
#
# - The **second key idea**, is that we will try to make the Gaussian distribution $q(z |x)$ as expressive as possible by using a neural net (the "Encoder'') to represent its mean and variance and we will have a second neural net (the "Decoder") to represent the mean of $p(x \vert z)$.
#
# In the next subsection we define these two nets.

# %% [markdown]
# ##Defining The Nets
#
# Assuming that $x \in \mathbb{R}^{\rm image-dimension}$, we *choose* an appropriate value of ${\rm latent-dimension}$ s.t $z \in \mathbb{R}^{\rm latent-dimension}$. Then the needed pair of nets can be denoted as,
#
#
# $$ {\rm Encoder}_{\Phi} : \mathbb{R}^{\rm image-dimension} \rightarrow \mathbb{R}^{\rm latent-dimension} \times \mathbb{R}^{\rm latent-dimension} $$
#
# $$ {\rm Decoder}_{\Theta} : \mathbb{R}^{\rm latent-dimension} \rightarrow \mathbb{R}^{\rm image-dimension} $$
#
#   In above $\Phi$ and $\Theta$ are to denote the set of all trainable weights in the Encoder and the Decoder respectively. In the particular implementation that will demonstrate here we shall have both these nets be of depth $3$ (and hence each of them will have $3$ affine transforms). The first two activation layers in each would be ${\rm hidden-dimension}$ sized ${\rm Leaky-ReLU}$ activations. The Encoder has 2 layers of activation while the Decoder will be using a third layer of sigmoid activations at the output.

# %% [markdown]
# ##Parameterizing The Distributions
#
# Given any data sample $\vec{x}$, we define the mean $\vec{\mu}$ and the diagonal variances $\vec{\sigma}$ of the assumed Gaussian, $q(\vec{z}|\vec{x})$ as,
#
# - $q(\vec{z} |\vec{x}) = q_{\Phi}(\vec{z} |\vec{x}) :=  {\cal N}(f({\rm Encoder}_{\Phi} (\vec{x})))$
#
# Where $f$ is a transformation -- that we shall soon specify -- which we shall do to the outputs of the ${\rm Encoder}_\Phi$ to obtain the mean and the variance of the Normal distribution of $q(\vec{z} | \vec{x})$.
#
# Given any sample $\vec{z}$ from $q_{\Phi}(\vec{z} |\vec{x})$, we let the $p$ be more general and only assume that,
#
# - $p(\vec{x} |\vec{z}) = p_{\Theta}(\vec{x} |\vec{z}) := \mathcal{N}({\rm Decoder}_{\Theta}(\vec{z}), {\rm diag(all{-}ones{-}vector)})$
#
# We assume that the distribution of the latent variable is just the standard normal,
#
# - $p(\vec{z}) = {\cal N}(0,I)$

# %% [markdown]
# ##The V.A.E.
#
# If we can sample $\vec{z_s} \sim q_{\Phi}(\vec{z}|\vec{x}) ~\forall s=1,\ldots,S$  then the  minimization objective -- the "**Variational Free Energy (V.F.E.)**" is replaced by its empirical (Monte Carlo) estimate,
#
# \begin{align*}
# {\rm Empirical ~V.F.E.} :=&- \color{blue}{\tilde{\mathbb{E}}_{q_{\Phi}} \log p_{\Theta}(\vec{x}|\vec{z})}  + \color{red}{ \tilde{\mathbb{E}}_{q_{\Phi}} \log \left (  \frac{q_\Phi(\vec{z}|\vec{x})}{p(\vec{z})} \right ) }\\
# = & \frac{1}{S} \sum_{s=1}^S \left \{ \underbrace{\color{blue}{- \log p_{\Theta}(\vec{x}|\vec{z_s})}}_{\rm Reconstuction Loss} + \underbrace{\color{red} { \log q_\Phi(\vec{z_s}|\vec{x}) - \log p(\vec{z_s})}}_{\rm KL-Divergence}  \right \}\\
# \end{align*}
#
#
#
# We note that, ``Variational Autoencoder (VAE)" is not a single architecture but a system which uses 2 neural nets for implementing the plan as said above for learning an unknown marginal distribution of the data $p(x)$ by approximating it as $p_{\Theta} (\vec{x}) := \int p_{\Theta} (\vec{x} | \vec{z}) p(\vec{z})$.

# %% [markdown]
# # Packages

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# zsh:1: command not found: nvidia-smi
# Your runtime has 17.2 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
import torch
import torch.nn as nn
#from torchinfosummary import summary (sometimes this works)
from torchsummary import summary
from torch.utils.data import random_split

import numpy as np
import torchvision
from tqdm import tqdm
from torchvision.utils import save_image, make_grid

import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/07/66t3_b054rvfmj8w0qdzlt800000gn/T/ipykernel_5383/966935592.py", line 1, in <module>
#     import torch
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/07/66t3_b054rvfmj8w0qdzlt800000gn/T/ipykernel_5383/966935592.py", line 12, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py", line 161, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/matplotlib/rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/matplotlib/colors.py", line 57, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/matplotlib/scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/matplotlib/ticker.py", line 143, in <module>
#     from matplotlib import transforms as mtransforms
#   File "/Users/abhishekbagde/anaconda3/lib/python3.11/site-packages/matplotlib/transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 12
#       9 from tqdm import tqdm
#      10 from torchvision.utils import save_image, make_grid
# ---> 12 import matplotlib.pyplot as plt
#      13 plt.style.use('seaborn-darkgrid')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib.cbook import sanitize_sequence
#     163 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/colors.py:57
#      55 import matplotlib as mpl
#      56 import numpy as np
# ---> 57 from matplotlib import _api, _cm, cbook, scale
#      58 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      61 class _ColorMapping(dict):
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/ticker.py:143
#     141 import matplotlib as mpl
#     142 from matplotlib import _api, cbook
# --> 143 from matplotlib import transforms as mtransforms
#     145 _log = logging.getLogger(__name__)
#     147 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     148            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     149            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     155            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     156            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# #Model and Optimization Hyperparameters

# %% [markdown]
# You can speed-up this code almost 3x if you run it on Google Colab
#
# --  and change settings as, Runtime ->Change runtime type ->Hardware Accelerator -> GPU
#
# -- and then set cuda=True below.

# %%
dataset_path = '~/datasets'

cuda = False #True
DEVICE = torch.device("cuda" if cuda else "cpu")


x_dim  = 784
#x_dim will be used as the value for the input_dim and output_dim below and it is the same as the image-dimension in the text above
hidden_dim = 1024
latent_dim = 8

lr = 1e-3
epochs = 31
#use number of epoch = something which is 1 + a multiple of 5
# - that keeps it consistent with the fact that the population risk is computed every 5 epochs.
train_size = 60000
#also try 60000
validation_size = 60000 - train_size
batch_size = 10**2
test_batch_size = 10**4

# %% [markdown]
# Check versions!

# %%
print(torch.__version__)
print(np.__version__)
print(torchvision.__version__)
# Out:
# 2.1.1
# 1.24.3
# 0.16.1

# %% [markdown]
# #The Dataset

# %%
from torchvision.datasets import MNIST, FashionMNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

mnist_transform = transforms.Compose([transforms.ToTensor(),])
#ToTensor converts the  data images to torch tensor
kwargs = {'num_workers': 1, 'pin_memory': True}
#The above is some setting with the GPUs

train_dataset = FashionMNIST(dataset_path, transform=mnist_transform, train=True, download=True)
test_dataset  = FashionMNIST(dataset_path, transform=mnist_transform, train=False, download=True)

train_dataset, validation_dataset = random_split(train_dataset, [train_size, validation_size])

#The above line redefines the train_dataset to use a randomly chosen train_size sized subset of the train_dataset
#Quite obviously using larger train_size should help.
#In this particular demonstration we shall not make use of the validation_dataset that gets produced above.
#Typically performance on the validation_dataset is what is used to determine good choices of achitecture and the step-lengths and the number of epochs.

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
test_loader  = DataLoader(dataset=test_dataset,  batch_size=test_batch_size, shuffle=False, **kwargs)

# %% [markdown]
# For various future purposes it is important to know that both the data options we work with above consist of 60000 training data and 10000 test data, and all being 28x28 black and white images. These 28x28 pixel values range from 0 to 255 - the smaller numbers closer to zero represent the darker shade while the larger numbers closer to 255 represent the lighter or the white shade.

# %%
test_size = len(test_dataset)
print(test_size)
train_size = len(train_dataset)
print(train_size)
# Out:
# 10000
# 60000

# %% [markdown]
# #Defining Our Variational AutoEncoder (VAE)
#
# NOTATION : Any quantity like $A_{\rm some-number}$ or $B_{\rm some-number}$ denotes an affine transformation between appropriate Euclidean spaces.  These are implemented in PyTorch via the keyword ``nn.Linear" - quite a misnomer!!

# %% [markdown]
# ##Defining The Encoder

# %%
class Encoder(nn.Module):

    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(Encoder, self).__init__()

        self.FC_layer_1 = nn.Linear(input_dim, hidden_dim)
        self.FC_layer_2 = nn.Linear(hidden_dim, hidden_dim)
        self.FC_mean  = nn.Linear(hidden_dim, latent_dim)
        self.FC_var   = nn.Linear (hidden_dim, latent_dim)

        self.LeakyReLU = nn.LeakyReLU(0.2)

        self.training = True

    def forward(self, x):
        h_1      = self.LeakyReLU(self.FC_layer_1(x))
        # R^{image_dim} \ni x -> = LeakyReLU(A_1(x)) = h_1 \in R^{hidden_dim}
        h_2       = self.LeakyReLU(self.FC_layer_2(h_1))
        # R^{hidden_dim} \ni h_1 -> LeakyReLU(A_2(h_1)) = h_2 \in R^{hidden_dim}
        mean     = self.FC_mean(h_2)
        log_var  = self.FC_var(h_2)
        # R^{hidden_dim} \ni h_2 -> (A_31(h_2),A_32(h_2)) = (mean,log_var) \in R^{hidden_dim} x R^{hidden_dim}

        # encoder produces mean and log of variance i.e., parameters of a Gaussian distribution "q"

        return mean, log_var


# So here the Encoder is a depth-3 net mapping R^{input_dim} -> R^{hidden_dim} x R^{hidden_dim} as x -> ( A31( ReLU(A2( ReLU(A1(x)) )) ), A32( ReLU(A2( ReLU(A1(x)) )) ) )

# %% [markdown]
# We define the following equivalences betwee the program variables and the mathematical variable,
#
# ${\tt input\_dim} = {\rm image-dimension}$
#
# ${\tt hidden\_dim} = {\rm hidden-dimension}$
#
# ${\tt latent\_dim} = {\rm latent-dimension}$
#
#
# Then the structure of the encoder defined above motivates the definintion of two sub-networks of the ${\rm Encoder}$ net as ${\rm Enc}_1$ and ${\rm Enc}_2$ to facilitate future description :
#
# \begin{align}
# {\rm Encoder} : \mathbb{R}^{\rm image-dimension} \rightarrow &\mathbb{R}^{\rm latent-dimension} \times \mathbb{R}^{\rm latent-dimension} \\
# \vec{x} \mapsto &({\rm Enc}_1 (\vec{x}),{\rm Enc}_2 (\vec{x}))
# = (A_{31}(\vec{h_2}),A_{32}(\vec{h_2})) = ({\rm mean}, {\rm log-var})\\
# &{\tt {\rm where , } ~\mathbb{R}^{\rm hidden-dimension} \ni \vec{h_2} = {\rm ReLU}( A_2 ({\rm ReLU} (A_1(\vec{x}))))}
# \end{align}
#
#
#
# Recall that any affine transform of the form $A_* : \mathbb{R}^m \rightarrow \mathbb{R}^n$ acts on an input vector $\vec{q}$ as $A_*(\vec{q}) = L_*(\vec{q}) + \vec{b}_*$ where $\vec{b}_* \in \mathbb{R}^n$ and $L_*$ is a $m \times n$ matrix. **Question :** In terms of ${\rm input/output/hidden - dimension}$ count how many trainable parameters does the encoder have?

# %% [markdown]
# ## Defining The Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_dim):
        super(Decoder, self).__init__()

        self.FC_dec_layer_1 = nn.Linear(latent_dim, hidden_dim)
        self.FC_dec_layer_2 = nn.Linear(hidden_dim, hidden_dim)
        self.FC_output = nn.Linear(hidden_dim, output_dim)

        self.LeakyReLU = nn.LeakyReLU(0.2)

    def forward(self, z):
        dec_h_1     = self.LeakyReLU(self.FC_dec_layer_1(z))
        # R^{latent_dim} \ni z -> ReLU(B1(z)) = dec_h_1 \in R^{hidden_dim}

        dec_h_2     = self.LeakyReLU(self.FC_dec_layer_2(dec_h_1))
        # R^{hidden_dim} \ni dec_h_1 -> ReLU(B2(dec_h_1)) = dec_h_2 \in R^{hidden_dim}

        x_hat = torch.sigmoid(self.FC_output(dec_h_2))
        #R^{hidden_dim} \ni dec_h_2 -> Sigmoid(B3(dec_h_2)) = x_hat \in R^{output_dim}

        return x_hat


# So here the Decoder is a depth-3 net mapping R^{latent_dim} -> R^{output_dim} as z -> Sigmoid(B3( ReLU(B2( ReLU(B1(z)) )) ))

# %% [markdown]
# We further define the following renaming between the program variables and the mathematical variable,
#
# ${\tt output\_dim} = {\rm decoder-output-dimension}$
#
#
#
#
# Recall that any affine transform of the form $A_* : \mathbb{R}^m \rightarrow \mathbb{R}^n$ acts on an input vector $\vec{q}$ as $A_*(\vec{q}) = L_*(\vec{q}) + \vec{b}_*$ where $\vec{b}_* \in \mathbb{R}^n$ and $L_*$ is a $m \times n$ matrix. **Question :** In terms of ${\rm input/output/hidden - dimension}$ count how many trainable parameters does the decoder have?

# %% [markdown]
# ## Combining The Encoder And The Decoder

# %%
def reparameterization(mean, var):
        epsilon = torch.randn_like(var).to(DEVICE)
        # sampling epsilon ~ N(0,I_{latent-dimension x latent-dimension})
        y = mean + var*epsilon
        # The so-called "reparameterization trick"
        return y

# %% [markdown]
# The above function specifies that $\vec{y}$ is a random variable s.t,
# $${\mathbb{R}}^{{\rm latent-dimension}} \ni {\vec y} \sim \vec{ {\rm mean}} + {\rm var} \times {\cal N}(0,I)) \sim {\cal N}(\vec{{\rm mean}}, {\rm diag(var^2)})$$

# %%
## Now we define the final model

class Model(nn.Module):
    def __init__(self, Encoder, Decoder):
        super(Model, self).__init__()

        self.Encoder = Encoder
        self.Decoder = Decoder


    def forward(self, x):
        mean, log_var = self.Encoder(x)
        y = reparameterization(mean, torch.exp(0.5 * log_var))
        x_hat = self.Decoder(y)

        return x_hat, mean, log_var

# %% [markdown]
# NOTE: In here we shall use the $\log$ and the $\exp$ to be acting coordinate-wise when applied to a vector.
#
# For every input (image) vector $\vec{x}$, the ``forward" function above does the following $3$ step computation,
#
# > STEP-1 : $$ (\vec{\mu_z}, 2\cdot \log(\vec{\sigma_z})) := {\rm Encoder}_{\Phi} (\vec{x})$$
#
# The "reparameterization" function is getting called with ${\tt mean} = \vec{\mu_z}$ and ${\tt var} = \exp({\frac{1}{2} \times 2\cdot \log(\vec{\sigma_z})}) = \vec{\sigma_z} $
#
#
# And it returns a sample of a random variable s.t,
# > STEP-2 : $${\vec z} \sim   {\cal N}(\vec{\mu_z},{\rm diag}(\vec{\sigma_z} \circ \vec{\sigma_z}))$$
#
# (There is a bit of a misnaming here since the word ${\tt var}$ might remind one of "variance" but as is clear from above its actually the ``standard deviation'' of the latent variable. But we shall stick with usual definitions for now.)
#
# Also the above 2 Steps together now effectively specify a choice of the function $f$ that was mentioned in the previous section, "Parameterizing The Distributions"
#
#
# >STEP-3 : $$\hat{x} = {\rm Decoder}_{\Theta}(\vec{z})$$
#
# Thus for every data $\vec{x}$ the ${\tt forward}$ function returns a $3-$tuple of vectors,
# $${\tt (x\_{hat}, mean, log\_var)} :=  (\hat{x},\vec{\mu_z}, 2\cdot \log(\vec{\sigma_z}))$$
#
#
#
# **In many usual neural net implementaions the ``forward" function/propagation just computes an output vector after evaluating some neural net at the given input. But in V.A.E. things are much more complicated! Here the forward function implements a "stochastic process'' which uses (two) neural nets, the input data and a source of randomization and computes a set of 3 vectors as given above - of which $\hat{x}$ is a random variable.**

# %%
encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
decoder = Decoder(latent_dim=latent_dim, hidden_dim = hidden_dim, output_dim = x_dim)

model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)


#(en)/(de)coder is an object of the class (En)/(De)coder
#model is an object of the class Model  - which takes as input entire objects encoder and the decoder

summary(model,(1,x_dim))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1              [-1, 1, 1024]         803,840
#          LeakyReLU-2              [-1, 1, 1024]               0
#             Linear-3              [-1, 1, 1024]       1,049,600
#          LeakyReLU-4              [-1, 1, 1024]               0
#             Linear-5                 [-1, 1, 8]           8,200
#             Linear-6                 [-1, 1, 8]           8,200
#            Encoder-7   [[-1, 1, 8], [-1, 1, 8]]               0
#             Linear-8              [-1, 1, 1024]           9,216
#          LeakyReLU-9              [-1, 1, 1024]               0
#            Linear-10              [-1, 1, 1024]       1,049,600
#         LeakyReLU-11              [-1, 1, 1024]               0
#            Linear-12               [-1, 1, 784]         803,600
#           Decoder-13               [-1, 1, 784]               0
# ================================================================
# Total params: 3,732,256
# Trainable params: 3,732,256
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.07
# Params size (MB): 14.24
# Estimated Total Size (MB): 14.31
# ----------------------------------------------------------------

# %% [markdown]
# The above instantiation of the VAE model crucially forced the following equuality between the different parameters,
#
# ${\rm image-dimension} (={\tt input\_dim})= {\rm decoder-output-dimension}(={\tt output\_dim}) = {\tt x\_dim}$

# %% [markdown]
# >This forcing of the input to the encoder and the output of the decoder to be the same dimension motivates the terminology of an ``autoencoder" - though **strictly speaking an "autoencoder" refers to a single neural net mapping $\mathbb{R}^k \rightarrow \mathbb{R}^k$ for some $k$ to be an autoencoder**. *V.A.E is not an autoencoder in the same sense* since it is **NOT** representatable as a single function from the input to the encoder to the outoput of the decoder.*

# %% [markdown]
# # Defining the Loss Function and the Optimizer

# %%
from torch.optim import Adam


# p(x|z) = N(x; x_hat, 1); x_hat = decoder(z)
def loss_function(x, x_hat, mean, log_var):
    MSE_Loss = nn.functional.mse_loss(x_hat, x, reduction='sum')
    KLD      = - 0.5 * torch.sum(1 + log_var - mean.pow(2) - (log_var).exp())
    # For dim = 1, torch.sum(a_ij, dim=1) = \sum_{j=1}^d a_ij
    # 1 here is an all ones matrix of size (minibatch_size, latent_dimension)
    return MSE_Loss + KLD


#optimizer = Adam(model.parameters(), lr=lr)
#weight_decay=0
optimizer = Adam(model.parameters(), lr=lr)

# %% [markdown]
# Recall the variable ${\tt batch\_size}$(say $=m$) that was defined earlier. Now we realize that this $m$ is the "mini-batch" size i.e the number of samples of data the eventual algorithm will use to define a stochastic gradient. Further recalling the definition of the ${\rm image-dimension}$ (the input dimension to the encoder) we realize that the function ${\rm loss\_function}$ is designed to get as input as set of $4$ matrices,
# - $2$ matrices ${\bf \tt x}, {\bf \tt x\_{\rm hat}} \in \mathbb{R}^{m \times {\rm image-dimension}}$
# - $2$ matrices, ${\tt mean, log\_var} \in \mathbb{R}^{m \times {\rm latent-dimension}}$
#
# **Although the above are the right matrix dimensions for how the code operates, for ease of exposition, in what follows we shall treat ${\tt (x\_{hat}, mean, log\_var)}$ as just vectors of appropriate dimensions as would be obtained from a single input data/image data $\vec{x}$**
#
# Towards understanding the above loss function computation recall the identification that we had established between the theoretical variables and the code variables, *(Recall that here $\log$ and $\exp$ applied to any vector shall be seen as being a shorthand for element-wise application)*
#
#
# $${\tt (x\_{hat}, mean, log\_var)} :=  (\hat{x},\vec{\mu_z}, 2\cdot \log(\vec{\sigma_z}))$$
#
#
# First we recall that we had defined, $p_{\Theta}(\vec{x} |\vec{z}) := \mathcal{N}({\rm Decoder}_{\Theta}(\vec{z}), {\rm diag(all{-}ones{-}vector)})$.Hence on any one input data $\vec{x}$ the ''Reconstruction Loss'' part of the Variational Free Energy is,
# In above one is computing,
#
# > First Term of V.F.E. =
#  $$ {\rm Reconstruction-Loss}(\vec{x}) = -\log p_{\Theta}(\vec{x}|\vec{z}) = \frac{1}{2}||{\vec{x}-{\rm Decoder}_{\Theta}(\vec{z})}||_2^2 = \frac{1}{2}||\vec{x}- \hat{x}||_2^2 $$
#
# In above we have recalled the definition of $\hat{x}$ from the definition of the ``forward" function.  Further recall, that we had defined, $p(\vec{x} |\vec{z}) = p_{\Theta}(\vec{x} |\vec{z}) := \mathcal{N}({\rm Decoder}_{\Theta}(\vec{z}), {\rm diag(all{-}ones{-}vector)})$ -- which implies that there should have been a second term in the above ${\rm Reconstruction-Loss}$ coming from the normalization constant in $\mathcal{N}({\rm Decoder}_{\Theta}(\vec{z}), {\rm diag(all{-}ones{-}vector)})$ - but we shall ignore it since its a constant and that doesnt affect the gradients that would get taken w.r.t the neural weights.
#
# Now let's recall the KL formula we had seen earlier,
#
# $${\rm KL}({\cal N}(\vec{\mu},\Sigma) || {\cal N}(0,I) ) =  \frac{-1}{2} \cdot \left [k + \log {\det (\Sigma)} - \Vert{\vec{\mu}}\Vert^2 - {\rm Tr} (\Sigma) \right ] $$
#
# This we need to invoke  for,
#
# $$ {\rm KL} (q_{\Phi}(\vec{z} |\vec{x}) \Vert p(\vec{z}) ) = {\rm KL} ({\cal N}(f({\rm Encoder}_{\Phi} (\vec{x}))) \Vert {\cal N}(0,I) )$$
#
# where, we recall that, ${\cal N}(f({\rm Encoder}_{\Phi} (\vec{x}))) = {\cal N}(\vec{\mu_z},\Sigma)$ with  $\Sigma = {\rm diag}(\vec{\sigma_z} \circ \vec{\sigma_z}) (= {\rm diag} (e^{{\tt log\_var}} ))$ and thus we have,
#
# > Second Term of V.F.E. =
# $${\rm KL} (q_{\Phi}(\vec{z} |\vec{x}) \Vert p(\vec{z}) ) = -\frac{1}{2} \cdot \sum_{i=1}^{\rm latent-dimension} \left [  1 +  ({\rm log\_var}_i) - {\rm mean}_i^2 - e^{ {\tt log\_var_i}}   \right ]$$
#
#
# Thus the loss being computed at data $\vec{x}$ is,
#
# \begin{align}
# &-\log p_{\Theta}(\vec{x}|\vec{z})  + {\rm KL} (q_{\Phi}(\vec{z} |\vec{x}) \Vert p(\vec{z}) )\\
# &= \frac{1}{2}||\vec{x}- \hat{x}||_2^2 -\frac{1}{2} \cdot \sum_{i=1}^{\rm latent-dimension} \left [  1 +  ({\rm log\_var}_i) - {\rm mean}_i^2 - e^{ {\tt log\_var_i}}   \right ]
# \end{align}

# %% [markdown]
# # Training The VAE

# %% [markdown]
# Takes 12 minutes without GPU on standard (F)MNIST at the following (most tested) settings :
#
# batch_size = 100,
# hidden_dim = 400,
# latent_dim = 200,
# lr = 1e-3,
# epochs = 20

# %%
print("The VAE training starts.")
model.train()
Training_Loss = []
Risk = []
Epoch = []
Risk_Epoch = []

for epoch in range(epochs):
    # At the beginning of each epoch we calculate the training and the test loss.
    training_loss = 0
    for batch_number, (r, _) in enumerate(train_loader):
            r = r.view(batch_size, x_dim)
            r = r.to(DEVICE)
            r_hat, mean, log_var = model(r)
            mini_batch_loss = loss_function(r, r_hat, mean, log_var)
            training_loss += mini_batch_loss.item()
            #mini_batch_loss.item() = training loss on the current mini-batch
            #training_loss is accumulating the mini-batch losses to compute the loss on the entire training data.

    Training_Loss.append(training_loss/(train_size))
    #Now we compute the test loss at the same model parameters at which the above training loss was calculated.
    if  epoch%5 == 0:
        test_loss = 0
        for test_batch_number, (t, _) in enumerate(test_loader):
                t = t.view(test_batch_size, x_dim)
                t = t.to(DEVICE)
                t_hat, mean, log_var = model(t)
                mini_batch_loss = loss_function(t, t_hat, mean, log_var)
                test_loss += mini_batch_loss.item()

        Risk.append(test_loss/(test_size))
        Risk_Epoch.append(epoch+1)

    for batch_number, (x, _) in enumerate(train_loader):
        x = x.view(batch_size, x_dim)
        x = x.to(DEVICE)

        #(x,_) pulls out a mini-batch from the train_loader which has now been converted into an enumeratable data type
        #There is some ancilliary information attached to each mini-batch which we dont care about and that is held in that "_"
        #batch_number adds 1 to itself everytime a mini-batch is pulled out
        #Thus the batch_number counts the number of mini-batches in the training data - a number we did not know till now.

        optimizer.zero_grad()

        x_hat, mean, log_var = model(x)
        mini_batch_loss = loss_function(x, x_hat, mean, log_var)
        mini_batch_loss.backward()
        optimizer.step()

    print("\tEpoch", epoch + 1, "complete!")

    Epoch.append(epoch+1)


print("The VAE training is over!")
# Out:
# The VAE training starts.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# The VAE training is over!

# %%
#Assignment 4

# %%
epochs = 31
# Define the sets of hidden layer sizes and latent dimensions
hidden_layer_sizes1 = [2**7, 2**8, 2**9, 2**10] 
latent_dimensions1 = [2**1, 2**2, 2**3, 2**4, 2**5, 2**6, 2**7, 2**8]

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Dictionary to store test losses for each configuration
test_losses1 = {}
list_total_parameter1 = []

for hidden_dim in hidden_layer_sizes1:
    for latent_dim in latent_dimensions1:
      # Initialize the model with the current configuration
        encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
        decoder = Decoder(latent_dim=latent_dim, hidden_dim=hidden_dim, output_dim=x_dim)
        encoder_params = count_parameters(encoder)
        decoder_params = count_parameters(decoder)
        total_params = encoder_params + decoder_params
        list_total_parameter1.append(total_params)
        model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)
        #weight_decay = 0
        optimizer = Adam(model.parameters(), lr=lr)

        print(f"The VAE training starts for hidden_dim={hidden_dim}, latent_dim={latent_dim}.")
        model.train()
        Training_Loss = []
        Risk = []
        Epoch = []
        Risk_Epoch = []

        for epoch in range(epochs):
            # At the beginning of each epoch we calculate the training and the test loss.
            training_loss = 0
            for batch_number, (r, _) in enumerate(train_loader):
                    r = r.view(batch_size, x_dim)
                    r = r.to(DEVICE)
                    r_hat, mean, log_var = model(r)
                    mini_batch_loss = loss_function(r, r_hat, mean, log_var)
                    training_loss += mini_batch_loss.item()
                    #mini_batch_loss.item() = training loss on the current mini-batch
                    #training_loss is accumulating the mini-batch losses to compute the loss on the entire training data.

            Training_Loss.append(training_loss/(train_size))
            #Now we compute the test loss at the same model parameters at which the above training loss was calculated.
            if  epoch%5 == 0:
                test_loss = 0
                for test_batch_number, (t, _) in enumerate(test_loader):
                        t = t.view(test_batch_size, x_dim)
                        t = t.to(DEVICE)
                        t_hat, mean, log_var = model(t)
                        mini_batch_loss = loss_function(t, t_hat, mean, log_var)
                        test_loss += mini_batch_loss.item()

                Risk.append(test_loss/(test_size))
                Risk_Epoch.append(epoch+1)

            for batch_number, (x, _) in enumerate(train_loader):
                x = x.view(batch_size, x_dim)
                x = x.to(DEVICE)

                #(x,_) pulls out a mini-batch from the train_loader which has now been converted into an enumeratable data type
                #There is some ancilliary information attached to each mini-batch which we dont care about and that is held in that "_"
                #batch_number adds 1 to itself everytime a mini-batch is pulled out
                #Thus the batch_number counts the number of mini-batches in the training data - a number we did not know till now.

                optimizer.zero_grad()

                x_hat, mean, log_var = model(x)
                mini_batch_loss = loss_function(x, x_hat, mean, log_var)
                mini_batch_loss.backward()
                optimizer.step()

            print("\tEpoch", epoch + 1, "complete!")

            Epoch.append(epoch+1)

        
        print(f"Training for hidden_dim={hidden_dim}, latent_dim={latent_dim} is over and risk is {Risk[-1]}!")
        test_losses1[(hidden_dim, latent_dim)] = Risk[-1]


print("The VAE training is over!")
# Out:
# The VAE training starts for hidden_dim=128, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=2 is over and risk is 27.075140625!
# The VAE training starts for hidden_dim=128, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=4 is over and risk is 24.288746875!
# The VAE training starts for hidden_dim=128, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=8 is over and risk is 23.995146875!
# The VAE training starts for hidden_dim=128, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=16 is over and risk is 23.988834375!
# The VAE training starts for hidden_dim=128, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=32 is over and risk is 23.895253125!
# The VAE training starts for hidden_dim=128, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=64 is over and risk is 24.08948125!
# The VAE training starts for hidden_dim=128, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=128 is over and risk is 24.1571234375!
# The VAE training starts for hidden_dim=128, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=256 is over and risk is 24.527009375!
# The VAE training starts for hidden_dim=256, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=2 is over and risk is 26.955659375!
# The VAE training starts for hidden_dim=256, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=4 is over and risk is 24.100509375!
# The VAE training starts for hidden_dim=256, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=8 is over and risk is 23.517103125!
# The VAE training starts for hidden_dim=256, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=16 is over and risk is 23.7290453125!
# The VAE training starts for hidden_dim=256, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=32 is over and risk is 23.81573125!
# The VAE training starts for hidden_dim=256, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=64 is over and risk is 23.9065484375!
# The VAE training starts for hidden_dim=256, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=128 is over and risk is 23.9503828125!
# The VAE training starts for hidden_dim=256, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=256 is over and risk is 24.04083125!
# The VAE training starts for hidden_dim=512, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=2 is over and risk is 26.89341875!
# The VAE training starts for hidden_dim=512, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=4 is over and risk is 23.976096875!
# The VAE training starts for hidden_dim=512, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=8 is over and risk is 23.3399796875!
# The VAE training starts for hidden_dim=512, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=16 is over and risk is 23.6220984375!
# The VAE training starts for hidden_dim=512, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=32 is over and risk is 23.637503125!
# The VAE training starts for hidden_dim=512, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=64 is over and risk is 23.7049515625!
# The VAE training starts for hidden_dim=512, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=128 is over and risk is 23.86318125!
# The VAE training starts for hidden_dim=512, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=256 is over and risk is 24.2811140625!
# The VAE training starts for hidden_dim=1024, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=2 is over and risk is 26.737209375!
# The VAE training starts for hidden_dim=1024, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=4 is over and risk is 23.9167765625!
# The VAE training starts for hidden_dim=1024, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=8 is over and risk is 23.502084375!
# The VAE training starts for hidden_dim=1024, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=16 is over and risk is 23.6933578125!
# The VAE training starts for hidden_dim=1024, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=32 is over and risk is 23.765896875!
# The VAE training starts for hidden_dim=1024, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=64 is over and risk is 23.7585140625!
# The VAE training starts for hidden_dim=1024, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=128 is over and risk is 24.156459375!
# The VAE training starts for hidden_dim=1024, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=256 is over and risk is 24.479928125!
# The VAE training is over!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming test_losses1 is a dictionary with keys as (hidden_dim, latent_dim)
# and values as the final test loss (or any metric you choose) for that configuration.

# Extracting hidden layer sizes and latent dimensions
hidden_layer_sizes1 = sorted(set(key[0] for key in test_losses1.keys()))
latent_dimensions1 = sorted(set(key[1] for key in test_losses1.keys()))

print(test_losses1)
# Preparing data for heatmap
data = np.array([[test_losses1[(h, l)] for l in latent_dimensions1] for h in hidden_layer_sizes1])
data = np.array(data).reshape(4,8)

# Creating a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".2f", xticklabels=latent_dimensions1, yticklabels=hidden_layer_sizes1)
plt.title('Test Loss for Different Hidden Layer Sizes and Latent Dimensions')
plt.xlabel('Latent Dimension')
plt.ylabel('Hidden Layer Size')
plt.show()
# Out:
# {(128, 2): 27.075140625, (128, 4): 24.288746875, (128, 8): 23.995146875, (128, 16): 23.988834375, (128, 32): 23.895253125, (128, 64): 24.08948125, (128, 128): 24.1571234375, (128, 256): 24.527009375, (256, 2): 26.955659375, (256, 4): 24.100509375, (256, 8): 23.517103125, (256, 16): 23.7290453125, (256, 32): 23.81573125, (256, 64): 23.9065484375, (256, 128): 23.9503828125, (256, 256): 24.04083125, (512, 2): 26.89341875, (512, 4): 23.976096875, (512, 8): 23.3399796875, (512, 16): 23.6220984375, (512, 32): 23.637503125, (512, 64): 23.7049515625, (512, 128): 23.86318125, (512, 256): 24.2811140625, (1024, 2): 26.737209375, (1024, 4): 23.9167765625, (1024, 8): 23.502084375, (1024, 16): 23.6933578125, (1024, 32): 23.765896875, (1024, 64): 23.7585140625, (1024, 128): 24.156459375, (1024, 256): 24.479928125}

# %%
#Assignment 5

# %%
import matplotlib.pyplot as plt

# Lists to store total parameters and corresponding test losses
test_variational_free_energy1 = []

vfe_values1 = [vfe for (_, vfe) in test_losses1]
    
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(list_total_parameter1, vfe_values1, label='Test VFE vs Architecture Sizes', color='blue')
plt.axvline(x=train_size, color='red', linestyle='--', label='Total Size of Training Data')
plt.plot(list_total_parameter1, vfe_values1, marker='o', linestyle='-', color='b', label='Test Variational Free Energy')
#plt.axvline(x=60000, color='r', linestyle='--', label='Size of Training Data (60,000)')

plt.xlabel('Sizes of Architectures/Total Parameters Trained')
plt.ylabel('Test Variational Free Energy')
plt.title('Test VFE vs Architectures/Total Parameters Trained Weight Decay 0.0')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
epochs = 31
# Define the sets of hidden layer sizes and latent dimensions
    hidden_layer_sizes2 = [5, 50, 200, 500]
    latent_dimensions2 = [5, 10, 100, 300]

# Dictionary to store test losses for each configuration
test_losses2 = {}
list_total_parameter2 = []

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

for hidden_dim in hidden_layer_sizes2:
    for latent_dim in latent_dimensions2:
      # Initialize the model with the current configuration
        encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
        decoder = Decoder(latent_dim=latent_dim, hidden_dim=hidden_dim, output_dim=x_dim)
        encoder_params = count_parameters(encoder)
        decoder_params = count_parameters(decoder)
        total_params = encoder_params + decoder_params
        list_total_parameter2.append(total_params)
        model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)
        #weight_decay = 0
        optimizer = Adam(model.parameters(), lr=lr)

        print(f"The VAE training starts for hidden_dim={hidden_dim}, latent_dim={latent_dim}.")
        model.train()
        Training_Loss = []
        Risk = []
        Epoch = []
        Risk_Epoch = []

        for epoch in range(epochs):
            # At the beginning of each epoch we calculate the training and the test loss.
            training_loss = 0
            for batch_number, (r, _) in enumerate(train_loader):
                    r = r.view(batch_size, x_dim)
                    r = r.to(DEVICE)
                    r_hat, mean, log_var = model(r)
                    mini_batch_loss = loss_function(r, r_hat, mean, log_var)
                    training_loss += mini_batch_loss.item()
                    #mini_batch_loss.item() = training loss on the current mini-batch
                    #training_loss is accumulating the mini-batch losses to compute the loss on the entire training data.

            Training_Loss.append(training_loss/(train_size))
            #Now we compute the test loss at the same model parameters at which the above training loss was calculated.
            if  epoch%5 == 0:
                test_loss = 0
                for test_batch_number, (t, _) in enumerate(test_loader):
                        t = t.view(test_batch_size, x_dim)
                        t = t.to(DEVICE)
                        t_hat, mean, log_var = model(t)
                        mini_batch_loss = loss_function(t, t_hat, mean, log_var)
                        test_loss += mini_batch_loss.item()

                Risk.append(test_loss/(test_size))
                Risk_Epoch.append(epoch+1)

            for batch_number, (x, _) in enumerate(train_loader):
                x = x.view(batch_size, x_dim)
                x = x.to(DEVICE)

                #(x,_) pulls out a mini-batch from the train_loader which has now been converted into an enumeratable data type
                #There is some ancilliary information attached to each mini-batch which we dont care about and that is held in that "_"
                #batch_number adds 1 to itself everytime a mini-batch is pulled out
                #Thus the batch_number counts the number of mini-batches in the training data - a number we did not know till now.

                optimizer.zero_grad()

                x_hat, mean, log_var = model(x)
                mini_batch_loss = loss_function(x, x_hat, mean, log_var)
                mini_batch_loss.backward()
                optimizer.step()

            print("\tEpoch", epoch + 1, "complete!")

            Epoch.append(epoch+1)

        
        print(f"Training for hidden_dim={hidden_dim}, latent_dim={latent_dim} is over and risk is {Risk[-1]}!")
        test_losses2[(hidden_dim, latent_dim)] = Risk[-1]


print("The VAE training is over!")
# Out:
# The VAE training starts for hidden_dim=5, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=5 is over and risk is 34.723703125!
# The VAE training starts for hidden_dim=5, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=10 is over and risk is 33.977690625!
# The VAE training starts for hidden_dim=5, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=100 is over and risk is 35.640928125!
# The VAE training starts for hidden_dim=5, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=300 is over and risk is 35.12589375!
# The VAE training starts for hidden_dim=50, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=5 is over and risk is 24.9086328125!
# The VAE training starts for hidden_dim=50, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=10 is over and risk is 24.8246125!
# The VAE training starts for hidden_dim=50, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=100 is over and risk is 24.948171875!
# The VAE training starts for hidden_dim=50, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=300 is over and risk is 25.01174375!
# The VAE training starts for hidden_dim=200, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=5 is over and risk is 23.7719296875!
# The VAE training starts for hidden_dim=200, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=10 is over and risk is 23.62073125!
# The VAE training starts for hidden_dim=200, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=100 is over and risk is 24.094325!
# The VAE training starts for hidden_dim=200, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=300 is over and risk is 24.263434375!
# The VAE training starts for hidden_dim=500, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=5 is over and risk is 23.560865625!
# The VAE training starts for hidden_dim=500, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=10 is over and risk is 23.714315625!
# The VAE training starts for hidden_dim=500, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=100 is over and risk is 23.837690625!
# The VAE training starts for hidden_dim=500, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=300 is over and risk is 24.2448484375!
# The VAE training is over!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming test_losses2 is a dictionary with keys as (hidden_dim, latent_dim)
# and values as the final test loss (or any metric you choose) for that configuration.

# Extracting hidden layer sizes and latent dimensions
hidden_layer_sizes2 = sorted(set(key[0] for key in test_losses2.keys()))
latent_dimensions2 = sorted(set(key[1] for key in test_losses2.keys()))

print(test_losses2)
# Preparing data for heatmap
data = np.array([[test_losses2[(h, l)] for l in latent_dimensions2] for h in hidden_layer_sizes2])
data = np.array(data).reshape(4,4)

# Creating a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".2f", xticklabels=latent_dimensions2, yticklabels=hidden_layer_sizes2)
plt.title('Test Loss for Different Hidden Layer Sizes and Latent Dimensions')
plt.xlabel('Latent Dimension')
plt.ylabel('Hidden Layer Size')
plt.show()
# Out:
# {(5, 5): 34.723703125, (5, 10): 33.977690625, (5, 100): 35.640928125, (5, 300): 35.12589375, (50, 5): 24.9086328125, (50, 10): 24.8246125, (50, 100): 24.948171875, (50, 300): 25.01174375, (200, 5): 23.7719296875, (200, 10): 23.62073125, (200, 100): 24.094325, (200, 300): 24.263434375, (500, 5): 23.560865625, (500, 10): 23.714315625, (500, 100): 23.837690625, (500, 300): 24.2448484375}

# %%
print(list_total_parameter2)
print(test_losses2)

all_values = list(test_losses2.values())
print(all_values)
# Out:
# [8779, 8864, 10394, 13794, 85144, 85904, 99584, 129984, 398194, 401204, 455384, 575784, 1294294, 1301804, 1436984, 1737384]
# {(5, 5): 34.723703125, (5, 10): 33.977690625, (5, 100): 35.640928125, (5, 300): 35.12589375, (50, 5): 24.9086328125, (50, 10): 24.8246125, (50, 100): 24.948171875, (50, 300): 25.01174375, (200, 5): 23.7719296875, (200, 10): 23.62073125, (200, 100): 24.094325, (200, 300): 24.263434375, (500, 5): 23.560865625, (500, 10): 23.714315625, (500, 100): 23.837690625, (500, 300): 24.2448484375}
# [34.723703125, 33.977690625, 35.640928125, 35.12589375, 24.9086328125, 24.8246125, 24.948171875, 25.01174375, 23.7719296875, 23.62073125, 24.094325, 24.263434375, 23.560865625, 23.714315625, 23.837690625, 24.2448484375]

# %%
import matplotlib.pyplot as plt

# Lists to store total parameters and corresponding test losses
test_variational_free_energy2 = []

list_total_parameter2 = [8779, 8864, 10394, 13794, 85144, 85904, 99584, 129984, 398194, 401204, 455384, 575784, 1294294, 1301804, 1436984, 1737384]
vfe_values2 = [34.723703125, 33.977690625, 35.640928125, 35.12589375, 24.9086328125, 24.8246125, 24.948171875, 25.01174375, 23.7719296875, 23.62073125, 24.094325, 24.263434375, 23.560865625, 23.714315625, 23.837690625, 24.2448484375]
    
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(list_total_parameter2, vfe_values2, label='Test VFE vs Architecture Sizes', color='blue')
plt.axvline(x=train_size, color='red', linestyle='--', label='Total Size of Training Data')
plt.plot(list_total_parameter2, vfe_values2, marker='o', linestyle='-', color='b', label='Test Variational Free Energy')
#plt.axvline(x=60000, color='r', linestyle='--', label='Size of Training Data (60,000)')

plt.xlabel('Sizes of Architectures/Total Parameters Trained')
plt.ylabel('Test Variational Free Energy')
plt.title('Test VFE vs Architectures/Total Parameters Trained Weight Decay 0.0')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
#Assignment 6

# %%
epochs = 31
# Define the sets of hidden layer sizes and latent dimensions
hidden_layer_sizes3 = [2**7, 2**8, 2**9, 2**10]
latent_dimensions3 = [2**1, 2**2, 2**3, 2**4, 2**5, 2**6, 2**7, 2**8]
#weight_decay=1e-3

test_losses3 = {}
list_total_parameter3 = []

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

for hidden_dim in hidden_layer_sizes3:
    for latent_dim in latent_dimensions3:
      # Initialize the model with the current configuration
        encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
        decoder = Decoder(latent_dim=latent_dim, hidden_dim=hidden_dim, output_dim=x_dim)
        encoder_params = count_parameters(encoder)
        decoder_params = count_parameters(decoder)
        total_params = encoder_params + decoder_params
        list_total_parameter3.append(total_params)
        model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)
        #weight_decay=0.001
        optimizer = Adam(model.parameters(), lr=lr, weight_decay=0.001)

        print(f"The VAE training starts for hidden_dim={hidden_dim}, latent_dim={latent_dim}.")
        model.train()
        Training_Loss = []
        Risk = []
        Epoch = []
        Risk_Epoch = []

        for epoch in range(epochs):
            # At the beginning of each epoch we calculate the training and the test loss.
            training_loss = 0
            for batch_number, (r, _) in enumerate(train_loader):
                    r = r.view(batch_size, x_dim)
                    r = r.to(DEVICE)
                    r_hat, mean, log_var = model(r)
                    mini_batch_loss = loss_function(r, r_hat, mean, log_var)
                    training_loss += mini_batch_loss.item()
                    #mini_batch_loss.item() = training loss on the current mini-batch
                    #training_loss is accumulating the mini-batch losses to compute the loss on the entire training data.
                  
            Training_Loss.append(training_loss/(train_size))
            #Now we compute the test loss at the same model parameters at which the above training loss was calculated.
            if  epoch%5 == 0:
                test_loss = 0
                for test_batch_number, (t, _) in enumerate(test_loader):
                        t = t.view(test_batch_size, x_dim)
                        t = t.to(DEVICE)
                        t_hat, mean, log_var = model(t)
                        mini_batch_loss = loss_function(t, t_hat, mean, log_var)
                        test_loss += mini_batch_loss.item()
                Risk.append(test_loss/(test_size))
                Risk_Epoch.append(epoch+1)

            for batch_number, (x, _) in enumerate(train_loader):
                x = x.view(batch_size, x_dim)
                x = x.to(DEVICE)
                #(x,_) pulls out a mini-batch from the train_loader which has now been converted into an enumeratable data type
                #There is some ancilliary information attached to each mini-batch which we dont care about and that is held in that "_"
                #batch_number adds 1 to itself everytime a mini-batch is pulled out
                #Thus the batch_number counts the number of mini-batches in the training data - a number we did not know till now.
                optimizer.zero_grad()
                x_hat, mean, log_var = model(x)
                mini_batch_loss = loss_function(x, x_hat, mean, log_var)
                mini_batch_loss.backward()
                optimizer.step()

            print("\tEpoch", epoch + 1, "complete!")

            Epoch.append(epoch+1)

        test_losses3[(hidden_dim, latent_dim)] = Risk[-1]
        print(f"Training for hidden_dim={hidden_dim}, latent_dim={latent_dim} and Risk is {Risk[-1]} is over!")

print("The VAE training is over!")
# Out:
# The VAE training starts for hidden_dim=128, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=2 and Risk is 27.30006875 is over!
# The VAE training starts for hidden_dim=128, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=4 and Risk is 24.2728015625 is over!
# The VAE training starts for hidden_dim=128, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=8 and Risk is 23.8880875 is over!
# The VAE training starts for hidden_dim=128, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=16 and Risk is 23.8008046875 is over!
# The VAE training starts for hidden_dim=128, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=32 and Risk is 23.958278125 is over!
# The VAE training starts for hidden_dim=128, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=64 and Risk is 23.9471015625 is over!
# The VAE training starts for hidden_dim=128, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=128 and Risk is 24.1657625 is over!
# The VAE training starts for hidden_dim=128, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=128, latent_dim=256 and Risk is 24.4690625 is over!
# The VAE training starts for hidden_dim=256, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=2 and Risk is 26.81235 is over!
# The VAE training starts for hidden_dim=256, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=4 and Risk is 23.988134375 is over!
# The VAE training starts for hidden_dim=256, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=8 and Risk is 23.5874890625 is over!
# The VAE training starts for hidden_dim=256, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=16 and Risk is 23.616946875 is over!
# The VAE training starts for hidden_dim=256, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=32 and Risk is 23.73173125 is over!
# The VAE training starts for hidden_dim=256, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=64 and Risk is 23.7575828125 is over!
# The VAE training starts for hidden_dim=256, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=128 and Risk is 23.849021875 is over!
# The VAE training starts for hidden_dim=256, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=256, latent_dim=256 and Risk is 24.015465625 is over!
# The VAE training starts for hidden_dim=512, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=2 and Risk is 26.846590625 is over!
# The VAE training starts for hidden_dim=512, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=4 and Risk is 23.976675 is over!
# The VAE training starts for hidden_dim=512, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=8 and Risk is 23.47521875 is over!
# The VAE training starts for hidden_dim=512, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=16 and Risk is 23.5211484375 is over!
# The VAE training starts for hidden_dim=512, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=32 and Risk is 23.760940625 is over!
# The VAE training starts for hidden_dim=512, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=64 and Risk is 23.979534375 is over!
# The VAE training starts for hidden_dim=512, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=128 and Risk is 24.009025 is over!
# The VAE training starts for hidden_dim=512, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=512, latent_dim=256 and Risk is 24.3111640625 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=2.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=2 and Risk is 26.897428125 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=4.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=4 and Risk is 24.0603 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=8.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=8 and Risk is 23.49286875 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=16.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=16 and Risk is 23.5936484375 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=32.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=32 and Risk is 23.74800625 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=64.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=64 and Risk is 23.91920625 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=128.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=128 and Risk is 23.91253125 is over!
# The VAE training starts for hidden_dim=1024, latent_dim=256.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=1024, latent_dim=256 and Risk is 24.400678125 is over!
# The VAE training is over!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming test_losses2 is a dictionary with keys as (hidden_dim, latent_dim)
# and values as the final test loss (or any metric you choose) for that configuration.

# Extracting hidden layer sizes and latent dimensions
hidden_layer_sizes3 = sorted(set(key[0] for key in test_losses3.keys()))
latent_dimensions3 = sorted(set(key[1] for key in test_losses3.keys()))

print(test_losses3)
# Preparing data for heatmap
data = np.array([[test_losses3[(h, l)] for l in latent_dimensions3] for h in hidden_layer_sizes3])
data = np.array(data).reshape(4,8)

# Creating a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".2f", xticklabels=latent_dimensions3, yticklabels=hidden_layer_sizes3)
plt.title('Test Loss for Different Hidden Layer Sizes and Latent Dimensions')
plt.xlabel('Latent Dimension')
plt.ylabel('Hidden Layer Size')
plt.show()
# Out:
# {(128, 2): 27.30006875, (128, 4): 24.2728015625, (128, 8): 23.8880875, (128, 16): 23.8008046875, (128, 32): 23.958278125, (128, 64): 23.9471015625, (128, 128): 24.1657625, (128, 256): 24.4690625, (256, 2): 26.81235, (256, 4): 23.988134375, (256, 8): 23.5874890625, (256, 16): 23.616946875, (256, 32): 23.73173125, (256, 64): 23.7575828125, (256, 128): 23.849021875, (256, 256): 24.015465625, (512, 2): 26.846590625, (512, 4): 23.976675, (512, 8): 23.47521875, (512, 16): 23.5211484375, (512, 32): 23.760940625, (512, 64): 23.979534375, (512, 128): 24.009025, (512, 256): 24.3111640625, (1024, 2): 26.897428125, (1024, 4): 24.0603, (1024, 8): 23.49286875, (1024, 16): 23.5936484375, (1024, 32): 23.74800625, (1024, 64): 23.91920625, (1024, 128): 23.91253125, (1024, 256): 24.400678125}

# %%
print(list_total_parameter3)
print(test_losses3)

all_values = list(test_losses3.values())
print(all_values)
# Out:
# [235540, 236312, 237856, 240944, 247120, 259472, 284176, 333584, 535828, 537368, 540448, 546608, 558928, 583568, 632848, 731408, 1333012, 1336088, 1342240, 1354544, 1379152, 1428368, 1526800, 1723664, 3713812, 3719960, 3732256, 3756848, 3806032, 3904400, 4101136, 4494608]
# {(128, 2): 27.30006875, (128, 4): 24.2728015625, (128, 8): 23.8880875, (128, 16): 23.8008046875, (128, 32): 23.958278125, (128, 64): 23.9471015625, (128, 128): 24.1657625, (128, 256): 24.4690625, (256, 2): 26.81235, (256, 4): 23.988134375, (256, 8): 23.5874890625, (256, 16): 23.616946875, (256, 32): 23.73173125, (256, 64): 23.7575828125, (256, 128): 23.849021875, (256, 256): 24.015465625, (512, 2): 26.846590625, (512, 4): 23.976675, (512, 8): 23.47521875, (512, 16): 23.5211484375, (512, 32): 23.760940625, (512, 64): 23.979534375, (512, 128): 24.009025, (512, 256): 24.3111640625, (1024, 2): 26.897428125, (1024, 4): 24.0603, (1024, 8): 23.49286875, (1024, 16): 23.5936484375, (1024, 32): 23.74800625, (1024, 64): 23.91920625, (1024, 128): 23.91253125, (1024, 256): 24.400678125}
# [27.30006875, 24.2728015625, 23.8880875, 23.8008046875, 23.958278125, 23.9471015625, 24.1657625, 24.4690625, 26.81235, 23.988134375, 23.5874890625, 23.616946875, 23.73173125, 23.7575828125, 23.849021875, 24.015465625, 26.846590625, 23.976675, 23.47521875, 23.5211484375, 23.760940625, 23.979534375, 24.009025, 24.3111640625, 26.897428125, 24.0603, 23.49286875, 23.5936484375, 23.74800625, 23.91920625, 23.91253125, 24.400678125]

# %%
import matplotlib.pyplot as plt

list_total_parameter3 = [235540, 236312, 237856, 240944, 247120, 259472, 284176, 333584, 535828, 537368, 540448, 546608, 558928, 583568, 632848, 731408, 1333012, 1336088, 1342240, 1354544, 1379152, 1428368, 1526800, 1723664, 3713812, 3719960, 3732256, 3756848, 3806032, 3904400, 4101136, 4494608]
vfe_values3 = [27.30006875, 24.2728015625, 23.8880875, 23.8008046875, 23.958278125, 23.9471015625, 24.1657625, 24.4690625, 26.81235, 23.988134375, 23.5874890625, 23.616946875, 23.73173125, 23.7575828125, 23.849021875, 24.015465625, 26.846590625, 23.976675, 23.47521875, 23.5211484375, 23.760940625, 23.979534375, 24.009025, 24.3111640625, 26.897428125, 24.0603, 23.49286875, 23.5936484375, 23.74800625, 23.91920625, 23.91253125, 24.400678125]

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(list_total_parameter3, vfe_values3, label='Test VFE vs Architecture Sizes', color='blue')
plt.axvline(x=train_size, color='red', linestyle='--', label='Total Size of Training Data')
plt.plot(list_total_parameter3, vfe_values3, marker='o', linestyle='-', color='b', label='Test Variational Free Energy')
#plt.axvline(x=60000, color='r', linestyle='--', label='Size of Training Data (60,000)')

plt.xlabel('Sizes of Architectures/Total Parameters Trained')
plt.ylabel('Test Variational Free Energy')
plt.title('Test VFE vs Architectures/Total Parameters Trained Weight Decay 0.001')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
epochs = 31
# Define the sets of hidden layer sizes and latent dimensions
hidden_layer_sizes4 = [5, 50, 200, 500]
latent_dimensions4 = [5, 10, 100, 300]

# Dictionary to store test losses for each configuration
test_losses4 = {}
list_total_parameter4 = []

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

for hidden_dim in hidden_layer_sizes4:
    for latent_dim in latent_dimensions4:
      # Initialize the model with the current configuration
        encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
        decoder = Decoder(latent_dim=latent_dim, hidden_dim=hidden_dim, output_dim=x_dim)
        encoder_params = count_parameters(encoder)
        decoder_params = count_parameters(decoder)
        total_params = encoder_params + decoder_params
        list_total_parameter4.append(total_params)
        model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)
        optimizer = Adam(model.parameters(), lr=lr, weight_decay=0.001)

        print(f"The VAE training starts for hidden_dim={hidden_dim}, latent_dim={latent_dim}.")
        model.train()
        Training_Loss = []
        Risk = []
        Epoch = []
        Risk_Epoch = []

        for epoch in range(epochs):
            # At the beginning of each epoch we calculate the training and the test loss.
            training_loss = 0
            for batch_number, (r, _) in enumerate(train_loader):
                    r = r.view(batch_size, x_dim)
                    r = r.to(DEVICE)
                    r_hat, mean, log_var = model(r)
                    mini_batch_loss = loss_function(r, r_hat, mean, log_var)
                    training_loss += mini_batch_loss.item()
                    #mini_batch_loss.item() = training loss on the current mini-batch
                    #training_loss is accumulating the mini-batch losses to compute the loss on the entire training data.

            Training_Loss.append(training_loss/(train_size))
            #Now we compute the test loss at the same model parameters at which the above training loss was calculated.
            if  epoch%5 == 0:
                test_loss = 0
                for test_batch_number, (t, _) in enumerate(test_loader):
                        t = t.view(test_batch_size, x_dim)
                        t = t.to(DEVICE)
                        t_hat, mean, log_var = model(t)
                        mini_batch_loss = loss_function(t, t_hat, mean, log_var)
                        test_loss += mini_batch_loss.item()

                Risk.append(test_loss/(test_size))
                Risk_Epoch.append(epoch+1)

            for batch_number, (x, _) in enumerate(train_loader):
                x = x.view(batch_size, x_dim)
                x = x.to(DEVICE)

                #(x,_) pulls out a mini-batch from the train_loader which has now been converted into an enumeratable data type
                #There is some ancilliary information attached to each mini-batch which we dont care about and that is held in that "_"
                #batch_number adds 1 to itself everytime a mini-batch is pulled out
                #Thus the batch_number counts the number of mini-batches in the training data - a number we did not know till now.

                optimizer.zero_grad()

                x_hat, mean, log_var = model(x)
                mini_batch_loss = loss_function(x, x_hat, mean, log_var)
                mini_batch_loss.backward()
                optimizer.step()

            print("\tEpoch", epoch + 1, "complete!")

            Epoch.append(epoch+1)

        test_losses4[(hidden_dim, latent_dim)] = Risk[-1]
        print(f"Training for hidden_dim={hidden_dim}, latent_dim={latent_dim} and Risk is {Risk[-1]} is over!")


print("The VAE training is over!")
# Out:
# The VAE training starts for hidden_dim=5, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=5 and Risk is 33.568125 is over!
# The VAE training starts for hidden_dim=5, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=10 and Risk is 32.05365 is over!
# The VAE training starts for hidden_dim=5, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=100 and Risk is 33.227284375 is over!
# The VAE training starts for hidden_dim=5, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=300 and Risk is 33.59281875 is over!
# The VAE training starts for hidden_dim=50, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=5 and Risk is 24.727571875 is over!
# The VAE training starts for hidden_dim=50, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=10 and Risk is 24.8309375 is over!
# The VAE training starts for hidden_dim=50, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=100 and Risk is 24.94185625 is over!
# The VAE training starts for hidden_dim=50, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=300 and Risk is 25.1126625 is over!
# The VAE training starts for hidden_dim=200, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=5 and Risk is 23.985478125 is over!
# The VAE training starts for hidden_dim=200, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=10 and Risk is 23.802915625 is over!
# The VAE training starts for hidden_dim=200, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=100 and Risk is 23.906509375 is over!
# The VAE training starts for hidden_dim=200, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=300 and Risk is 24.372971875 is over!
# The VAE training starts for hidden_dim=500, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=5 and Risk is 23.57893125 is over!
# The VAE training starts for hidden_dim=500, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=10 and Risk is 23.56343125 is over!
# The VAE training starts for hidden_dim=500, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=100 and Risk is 23.893571875 is over!
# The VAE training starts for hidden_dim=500, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=300 and Risk is 24.493546875 is over!
# The VAE training is over!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming test_losses2 is a dictionary with keys as (hidden_dim, latent_dim)
# and values as the final test loss (or any metric you choose) for that configuration.

# Extracting hidden layer sizes and latent dimensions
hidden_layer_sizes4 = sorted(set(key[0] for key in test_losses4.keys()))
latent_dimensions4 = sorted(set(key[1] for key in test_losses4.keys()))

print(test_losses4)
# Preparing data for heatmap
data = np.array([[test_losses4[(h, l)] for l in latent_dimensions4] for h in hidden_layer_sizes4])
data = np.array(data).reshape(4,4)

# Creating a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".2f", xticklabels=latent_dimensions4, yticklabels=hidden_layer_sizes4)
plt.title('Test Loss for Different Hidden Layer Sizes and Latent Dimensions  \n Weight Decay = 0.001')
plt.xlabel('Latent Dimension')
plt.ylabel('Hidden Layer Size')
plt.show()
# Out:
# {(5, 5): 33.568125, (5, 10): 32.05365, (5, 100): 33.227284375, (5, 300): 33.59281875, (50, 5): 24.727571875, (50, 10): 24.8309375, (50, 100): 24.94185625, (50, 300): 25.1126625, (200, 5): 23.985478125, (200, 10): 23.802915625, (200, 100): 23.906509375, (200, 300): 24.372971875, (500, 5): 23.57893125, (500, 10): 23.56343125, (500, 100): 23.893571875, (500, 300): 24.493546875}

# %%
print(list_total_parameter4)
print(test_losses4)

all_values = list(test_losses4.values())
print(all_values)
# Out:
# [8779, 8864, 10394, 13794, 85144, 85904, 99584, 129984, 398194, 401204, 455384, 575784, 1294294, 1301804, 1436984, 1737384]
# {(5, 5): 33.568125, (5, 10): 32.05365, (5, 100): 33.227284375, (5, 300): 33.59281875, (50, 5): 24.727571875, (50, 10): 24.8309375, (50, 100): 24.94185625, (50, 300): 25.1126625, (200, 5): 23.985478125, (200, 10): 23.802915625, (200, 100): 23.906509375, (200, 300): 24.372971875, (500, 5): 23.57893125, (500, 10): 23.56343125, (500, 100): 23.893571875, (500, 300): 24.493546875}
# [33.568125, 32.05365, 33.227284375, 33.59281875, 24.727571875, 24.8309375, 24.94185625, 25.1126625, 23.985478125, 23.802915625, 23.906509375, 24.372971875, 23.57893125, 23.56343125, 23.893571875, 24.493546875]

# %%
import matplotlib.pyplot as plt

# Lists to store total parameters and corresponding test losses
test_variational_free_energy4 = []

list_total_parameter4 = [8779, 8864, 10394, 13794, 85144, 85904, 99584, 129984, 398194, 401204, 455384, 575784, 1294294, 1301804, 1436984, 1737384]
vfe_values4 = [33.568125, 32.05365, 33.227284375, 33.59281875, 24.727571875, 24.8309375, 24.94185625, 25.1126625, 23.985478125, 23.802915625, 23.906509375, 24.372971875, 23.57893125, 23.56343125, 23.893571875, 24.493546875]

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(list_total_parameter4, vfe_values4, label='Test VFE vs Architecture Sizes', color='blue')
plt.axvline(x=train_size, color='red', linestyle='--', label='Total Size of Training Data')
plt.plot(list_total_parameter4, vfe_values4, marker='o', linestyle='-', color='b', label='Test Variational Free Energy')
#plt.axvline(x=60000, color='r', linestyle='--', label='Size of Training Data (60,000)')

plt.xlabel('Sizes of Architectures/Total Parameters Trained')
plt.ylabel('Test Variational Free Energy')
plt.title('Test VFE vs Architectures/Total Parameters Trained Weight Decay 0.001')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
epochs = 31
# Define the sets of hidden layer sizes and latent dimensions
hidden_layer_sizes6 = [5, 50, 200, 500]
latent_dimensions6 = [5, 10, 100, 300]

# Dictionary to store test losses for each configuration
test_losses6 = {}
list_total_parameter6 = []

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

for hidden_dim in hidden_layer_sizes6:
    for latent_dim in latent_dimensions6:
      # Initialize the model with the current configuration
        encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
        decoder = Decoder(latent_dim=latent_dim, hidden_dim=hidden_dim, output_dim=x_dim)
        encoder_params = count_parameters(encoder)
        decoder_params = count_parameters(decoder)
        total_params = encoder_params + decoder_params
        list_total_parameter6.append(total_params)
        model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)
        optimizer = Adam(model.parameters(), lr=lr, weight_decay=0.1)

        print(f"The VAE training starts for hidden_dim={hidden_dim}, latent_dim={latent_dim}.")
        model.train()
        Training_Loss = []
        Risk = []
        Epoch = []
        Risk_Epoch = []

        for epoch in range(epochs):
            # At the beginning of each epoch we calculate the training and the test loss.
            training_loss = 0
            for batch_number, (r, _) in enumerate(train_loader):
                    r = r.view(batch_size, x_dim)
                    r = r.to(DEVICE)
                    r_hat, mean, log_var = model(r)
                    mini_batch_loss = loss_function(r, r_hat, mean, log_var)
                    training_loss += mini_batch_loss.item()
                    #mini_batch_loss.item() = training loss on the current mini-batch
                    #training_loss is accumulating the mini-batch losses to compute the loss on the entire training data.

            Training_Loss.append(training_loss/(train_size))
            #Now we compute the test loss at the same model parameters at which the above training loss was calculated.
            if  epoch%5 == 0:
                test_loss = 0
                for test_batch_number, (t, _) in enumerate(test_loader):
                        t = t.view(test_batch_size, x_dim)
                        t = t.to(DEVICE)
                        t_hat, mean, log_var = model(t)
                        mini_batch_loss = loss_function(t, t_hat, mean, log_var)
                        test_loss += mini_batch_loss.item()

                Risk.append(test_loss/(test_size))
                Risk_Epoch.append(epoch+1)

            for batch_number, (x, _) in enumerate(train_loader):
                x = x.view(batch_size, x_dim)
                x = x.to(DEVICE)

                #(x,_) pulls out a mini-batch from the train_loader which has now been converted into an enumeratable data type
                #There is some ancilliary information attached to each mini-batch which we dont care about and that is held in that "_"
                #batch_number adds 1 to itself everytime a mini-batch is pulled out
                #Thus the batch_number counts the number of mini-batches in the training data - a number we did not know till now.

                optimizer.zero_grad()

                x_hat, mean, log_var = model(x)
                mini_batch_loss = loss_function(x, x_hat, mean, log_var)
                mini_batch_loss.backward()
                optimizer.step()

            print("\tEpoch", epoch + 1, "complete!")

            Epoch.append(epoch+1)

        test_losses6[(hidden_dim, latent_dim)] = Risk[-1]
        print(f"Training for hidden_dim={hidden_dim}, latent_dim={latent_dim} and Risk is {Risk[-1]} is over!")


print("The VAE training is over!")
# Out:
# The VAE training starts for hidden_dim=5, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=5 and Risk is 33.72265625 is over!
# The VAE training starts for hidden_dim=5, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=10 and Risk is 31.28115 is over!
# The VAE training starts for hidden_dim=5, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=100 and Risk is 33.006346875 is over!
# The VAE training starts for hidden_dim=5, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=5, latent_dim=300 and Risk is 31.74508125 is over!
# The VAE training starts for hidden_dim=50, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=5 and Risk is 24.8944171875 is over!
# The VAE training starts for hidden_dim=50, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=10 and Risk is 25.0509 is over!
# The VAE training starts for hidden_dim=50, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=100 and Risk is 25.049453125 is over!
# The VAE training starts for hidden_dim=50, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=50, latent_dim=300 and Risk is 25.300625 is over!
# The VAE training starts for hidden_dim=200, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=5 and Risk is 24.1387625 is over!
# The VAE training starts for hidden_dim=200, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=10 and Risk is 24.0524375 is over!
# The VAE training starts for hidden_dim=200, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=100 and Risk is 24.359115625 is over!
# The VAE training starts for hidden_dim=200, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=200, latent_dim=300 and Risk is 24.404184375 is over!
# The VAE training starts for hidden_dim=500, latent_dim=5.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=5 and Risk is 24.1520296875 is over!
# The VAE training starts for hidden_dim=500, latent_dim=10.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=10 and Risk is 23.87431875 is over!
# The VAE training starts for hidden_dim=500, latent_dim=100.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=100 and Risk is 24.12299375 is over!
# The VAE training starts for hidden_dim=500, latent_dim=300.
# 	Epoch 1 complete!
# 	Epoch 2 complete!
# 	Epoch 3 complete!
# 	Epoch 4 complete!
# 	Epoch 5 complete!
# 	Epoch 6 complete!
# 	Epoch 7 complete!
# 	Epoch 8 complete!
# 	Epoch 9 complete!
# 	Epoch 10 complete!
# 	Epoch 11 complete!
# 	Epoch 12 complete!
# 	Epoch 13 complete!
# 	Epoch 14 complete!
# 	Epoch 15 complete!
# 	Epoch 16 complete!
# 	Epoch 17 complete!
# 	Epoch 18 complete!
# 	Epoch 19 complete!
# 	Epoch 20 complete!
# 	Epoch 21 complete!
# 	Epoch 22 complete!
# 	Epoch 23 complete!
# 	Epoch 24 complete!
# 	Epoch 25 complete!
# 	Epoch 26 complete!
# 	Epoch 27 complete!
# 	Epoch 28 complete!
# 	Epoch 29 complete!
# 	Epoch 30 complete!
# 	Epoch 31 complete!
# Training for hidden_dim=500, latent_dim=300 and Risk is 24.51723125 is over!
# The VAE training is over!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming test_losses2 is a dictionary with keys as (hidden_dim, latent_dim)
# and values as the final test loss (or any metric you choose) for that configuration.

# Extracting hidden layer sizes and latent dimensions
hidden_layer_sizes6 = sorted(set(key[0] for key in test_losses6.keys()))
latent_dimensions6 = sorted(set(key[1] for key in test_losses6.keys()))

print(test_losses6)
# Preparing data for heatmap
data = np.array([[test_losses6[(h, l)] for l in latent_dimensions6] for h in hidden_layer_sizes6])
data = np.array(data).reshape(4,4)

# Creating a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".2f", xticklabels=latent_dimensions6, yticklabels=hidden_layer_sizes6)
plt.title('Test Loss for Different Hidden Layer Sizes and Latent Dimensions \n Weight Decay = 0.1')
plt.xlabel('Latent Dimension')
plt.ylabel('Hidden Layer Size')
plt.show()
# Out:
# {(5, 5): 33.72265625, (5, 10): 31.28115, (5, 100): 33.006346875, (5, 300): 31.74508125, (50, 5): 24.8944171875, (50, 10): 25.0509, (50, 100): 25.049453125, (50, 300): 25.300625, (200, 5): 24.1387625, (200, 10): 24.0524375, (200, 100): 24.359115625, (200, 300): 24.404184375, (500, 5): 24.1520296875, (500, 10): 23.87431875, (500, 100): 24.12299375, (500, 300): 24.51723125}

# %%
print(list_total_parameter6)
print(test_losses6)

all_values = list(test_losses6.values())
print(all_values)
# Out:
# [8779, 8864, 10394, 13794, 85144, 85904, 99584, 129984, 398194, 401204, 455384, 575784, 1294294, 1301804, 1436984, 1737384]
# {(5, 5): 33.72265625, (5, 10): 31.28115, (5, 100): 33.006346875, (5, 300): 31.74508125, (50, 5): 24.8944171875, (50, 10): 25.0509, (50, 100): 25.049453125, (50, 300): 25.300625, (200, 5): 24.1387625, (200, 10): 24.0524375, (200, 100): 24.359115625, (200, 300): 24.404184375, (500, 5): 24.1520296875, (500, 10): 23.87431875, (500, 100): 24.12299375, (500, 300): 24.51723125}
# [33.72265625, 31.28115, 33.006346875, 31.74508125, 24.8944171875, 25.0509, 25.049453125, 25.300625, 24.1387625, 24.0524375, 24.359115625, 24.404184375, 24.1520296875, 23.87431875, 24.12299375, 24.51723125]

# %%
import matplotlib.pyplot as plt

# Lists to store total parameters and corresponding test losses
test_variational_free_energy4 = []

list_total_parameter4 = [8779, 8864, 10394, 13794, 85144, 85904, 99584, 129984, 398194, 401204, 455384, 575784, 1294294, 1301804, 1436984, 1737384]
vfe_values4 = [33.72265625, 31.28115, 33.006346875, 31.74508125, 24.8944171875, 25.0509, 25.049453125, 25.300625, 24.1387625, 24.0524375, 24.359115625, 24.404184375, 24.1520296875, 23.87431875, 24.12299375, 24.51723125]

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(list_total_parameter4, vfe_values4, label='Test VFE vs Architecture Sizes', color='blue')
plt.axvline(x=train_size, color='red', linestyle='--', label='Total Size of Training Data')
plt.plot(list_total_parameter4, vfe_values4, marker='o', linestyle='-', color='b', label='Test Variational Free Energy')
#plt.axvline(x=60000, color='r', linestyle='--', label='Size of Training Data (60,000)')

plt.xlabel('Sizes of Architectures/Total Parameters Trained')
plt.ylabel('Test Variational Free Energy')
plt.title('Test VFE vs Architectures/Total Parameters Trained Weight Decay 0.1')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Understanding the Dynamics of the Training Loss & the Population Risk

# %%
train, = plt.plot(Epoch, Training_Loss, label=("Empirical Loss"))
test, = plt.plot(Risk_Epoch, Risk, label= ("Population Risk"))
plt.legend(handles=[train, test])

plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
print ("Number of Training Batches =",batch_number+1," & Number of Test Batches =",test_batch_number+1)
print ("Mini-Batch Size =",batch_size)
# Out:
# Number of Training Batches = 600  & Number of Test Batches = 1
# Mini-Batch Size = 100

# %% [markdown]
# # The Trained "model" Can Map The Test Data to Itself - Almost!

# %%
model.eval()

with torch.no_grad():
    for batch_idx, (x, _) in enumerate(tqdm(test_loader)):
        x = x.view(test_batch_size, x_dim)
        x = x.to(DEVICE)

        x_hat, _, _ = model(x)

        break


def show_image(x, idx):
    x = x.view(test_batch_size, 28, 28)
    fig = plt.figure()
    plt.imshow(x[idx].cpu().numpy())
# Out:
#   0%|                                                     | 0/1 [00:01<?, ?it/s]

# %%
show_image(x, idx=8)

# %%
show_image(x_hat, idx=8)

# %% [markdown]
# Recall that the later of the 2 images ${\tt x\_hat}$($\tt idx$ element of it) is the output when the VAE gets the fist image ${\tt x}$($\tt idx$ element of it) as input.
#
# Thus the two images being close implies that the VAE was able to almost successfully reconstruct its input - as it was needed to do!
#
# Also note that the above test was run on test data - thats unseen data for the training - and hence this is testing **``generalizability"**
#
# --  i.e whether the VAE is doing the good reconstructions on new data that it was not trained on.

# %% [markdown]
# # Trained Decoder Generates Images From Pure Noise!
#
# We note that the trained decoder can map random Gaussian noise samples to meaningful images!

# %%
with torch.no_grad():
    noise = torch.randn(test_batch_size, latent_dim).to(DEVICE)
    generated_images = decoder(noise)

save_image(generated_images.view(test_batch_size, 1, 28, 28), 'generated_sample.png')

# %%
show_image(generated_images, idx=12)

# %%
show_image(generated_images, idx=0)

# %%
show_image(generated_images, idx=1)

# %%
show_image(generated_images, idx=10)

# %%
show_image(generated_images, idx=20)

# %%
show_image(generated_images, idx=50)
